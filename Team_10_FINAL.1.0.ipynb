# %% [markdown]
# <h1>Dynamic Team Introduction Team 10</h1>
#
#
# Welcome to Team 10’s dynamic introduction!!
#
# We are a group of five people from five different countries in 3 continents. Ryo is from Yokohama, Japan, Bianca is from Manila, Philippines, Roger is from Barcelona, Spain, Tebatso is from Bulawayo, Zimbabwe, and Piyush is from Bihar, India. Our team speaks a total of 17 languages.
#
# We are all currently completing our Master of Science degree in Business Analytics at Hult International Business School because we all want to be data analysts in the future. Oh, and by the way, we are already looking for summer internships that’s why we created this interactive code so you can learn more about our awesome team and our qualifications 😉.
#
# Team members:
# Bianca Rivas,
# Roger Lopez Benet,
# Piyush Kumar,
# Tebatso Nyarambi,
# Ryosuke Ogata.

# %%
# introduce the input user name 

print("What's your name:    ")
 
visitor = input().capitalize()




print(f"""Hello {visitor}. Welcome to group 10's dynamic introduction.""")

# instantiating lists having 3 different data
# Data 1 : Members list
name_lst = ['Ryo', 'Roger', 'Bianca', 'Piyush','Tebatso']
# Data 2 : Info Category list
info_lst_common = ['hobbies', 'nationality', 'work background', "aspires to be", 'favorite cuisine', "travel destination", "special talents"]
# Data 3 : Info for each members
Ryo = ["Basketball","Japanese","IT", "Data Scientist",'Ramen','Moon','Sleeping whole day']
Roger = ["Golf","Spanish","Marketing Manager", "Mark Zuckerberg", "Japanese", "Mars and beyond", "sleeping on a plane"]
Bianca = ["Reading, swimming, and traveling", "Filipino", "Wealth Management","Economic Analyst", "Japanese","anywhere she can free dive", "eat 50 pieces of nigiri in one sitting"]
Piyush = ["Listening Music, Travelling", "India", "Electrical Engineer", "Sundar Pichai", "Indian Food", "Europe", "Patience"]
Tebatso = ["she's a mad-scientist in the kitchen!", "Zimbabwean", "Retail Banking", "Rich", "Latino & Indian", "Mexico & Japan", "Laughing"]
Member_info = [Ryo,Roger,Bianca,Piyush,Tebatso]

# Below are all temporary variables to make system work
user_name = ""
info = ""
temp = 0
info_lst = []


# -----------------------------------------------------------------------------------------------------------------------
# To show all members names 
print(f"""
Pick one name from the list below, that you want to know 
{name_lst}
Name : """)
# To input member name who user want to see
user_name = input()

# To recognize which a member is selected by user
if user_name.capitalize() == name_lst[0]:
  temp = 0
elif user_name.capitalize() == name_lst[1]:
  temp = 1
elif user_name.capitalize() == name_lst[2]:
  temp = 2
elif user_name.capitalize() == name_lst[3]:
  temp = 3
elif user_name.capitalize() == name_lst[4]:
  temp = 4
else:
  print("your input was not in the member list, so system automatically picked one of members")

# To define a member info to show, based on user input
info_lst = Member_info[temp]
# To remove a member info from list, which is already showed
Member_info.pop(temp)

# To show a member info, which is defined based on user input
print(f"""
    {name_lst[temp]}'s {info_lst_common[0]} is {info_lst[0]}.
    {name_lst[temp]} 's {info_lst_common[1]} is {info_lst[1]}. {name_lst[temp]}'s' {info_lst_common[2]} is {info_lst[2]} 
    and {info_lst_common[3]} a {info_lst[3]}. 
    
    {name_lst[temp]}'s {info_lst_common[4]} is {info_lst[4]} and favorite {info_lst_common[5]} is {info_lst[5]}. 
    
    Did you know that {name_lst[temp]}'s {info_lst_common[6]} is {info_lst[6]}!!""")

print("-----------------------------------------------") 
# To remove a member name from list, which is already showed
name_lst.pop(temp)

# -----------------------------------------------------------------------------------------------------------------------

# To show all members names 
print(f"""
Pick one name from the list below, that you want to know 
{name_lst}
Name : """)
# To input member name who user want to see
user_name = input()

# To recognize which a member is selected by user
if user_name.capitalize() == name_lst[0]:
  temp = 0
elif user_name.capitalize() == name_lst[1]:
  temp = 1
elif user_name.capitalize() == name_lst[2]:
  temp = 2
elif user_name.capitalize() == name_lst[3]:
  temp = 3
else:
  print("Your input was not in the member list, so system automatically picked one of members")

# To define a member info to show, based on user input
info_lst = Member_info[temp]
# To remove a member info from list, which is already showed
Member_info.pop(temp)
# To show a member info, which is defined based on user input
print(f"""
    {name_lst[temp]}'s {info_lst_common[0]} is {info_lst[0]}.
    {name_lst[temp]} 's {info_lst_common[1]} is {info_lst[1]}. {name_lst[temp]}'s' {info_lst_common[2]} is {info_lst[2]} 
    and {info_lst_common[3]} a {info_lst[3]}. 
    
    {name_lst[temp]}'s {info_lst_common[4]} is {info_lst[4]} and favorite {info_lst_common[5]} is {info_lst[5]}. 
    
    Did you know that {name_lst[temp]}'s {info_lst_common[6]} is {info_lst[6]}!!""")

print("-----------------------------------------------") 
# To remove a member name from list, which is already showed
name_lst.pop(temp)

# -----------------------------------------------------------------------------------------------------------------------
# To show all members names
print(f"""
Pick one name from the list below, that you want to know 
{name_lst}
Name : """)
# To input member name who user want to see
user_name = input()

# To recognize which a member is selected by user
if user_name.capitalize() == name_lst[0]:
  temp = 0
elif user_name.capitalize() == name_lst[1]:
  temp = 1
elif user_name.capitalize() == name_lst[2]:
  temp = 2
else:
  print("your input was not in the member list, so system automatically picked one of members")

# To define a member info to show, based on user input
info_lst = Member_info[temp]
# To remove a member info from list, which is already showed
Member_info.pop(temp)

# To show a member info, which is defined based on user input
print(f"""
    {name_lst[temp]}'s {info_lst_common[0]} is {info_lst[0]}.
    {name_lst[temp]} 's {info_lst_common[1]} is {info_lst[1]}. {name_lst[temp]}'s' {info_lst_common[2]} is {info_lst[2]} 
    and {info_lst_common[3]} a {info_lst[3]}. 
    
    {name_lst[temp]}'s {info_lst_common[4]} is {info_lst[4]} and favorite {info_lst_common[5]} is {info_lst[5]}. 
    
    Did you know that {name_lst[temp]}'s {info_lst_common[6]} is {info_lst[6]}!!""")

print("-----------------------------------------------") 
# To remove a member name from list, which is already showed
name_lst.pop(temp)

# -----------------------------------------------------------------------------------------------------------------------
# To show all members names
print(f"""
Pick one name from the list below, that you want to know 
{name_lst}
Name : """)
# To input member name who user want to see
user_name = input()

# To recognize which a member is selected by user
if user_name.capitalize() == name_lst[0]:
  temp = 0
elif user_name.capitalize() == name_lst[1]:
  temp = 1
else:
  print("your input was not in the member list, so system automatically picked one of members")

# To define a member info to show, based on user input
info_lst = Member_info[temp]
# To remove a member info from list, which is already showed
Member_info.pop(temp)

# To show a member info, which is defined based on user input
print(f"""
    {name_lst[temp]}'s {info_lst_common[0]} is {info_lst[0]}.
    {name_lst[temp]} 's {info_lst_common[1]} is {info_lst[1]}. {name_lst[temp]}'s' {info_lst_common[2]} is {info_lst[2]} 
    and {info_lst_common[3]} a {info_lst[3]}. 
    
    {name_lst[temp]}'s {info_lst_common[4]} is {info_lst[4]} and favorite {info_lst_common[5]} is {info_lst[5]}. 
    
    Did you know that {name_lst[temp]}'s {info_lst_common[6]} is {info_lst[6]}!!""")

print("-----------------------------------------------") 
# To remove a member name from list, which is already showed
name_lst.pop(temp)

# -----------------------------------------------------------------------------------------------------------------------
# To show all members names
print(f"""
Pick one name from the list below, that you want to know 
{name_lst}
Name : """)
# To input member name who user want to see
user_name = input()

# To recognize which a member is selected by user
if user_name.capitalize() == name_lst[0]:
  temp = 0
else:
  print("your input was not in the member list, so system automatically picked one of members")

# To define a member info to show, based on user input
info_lst = Member_info[temp]
# To remove a member info from list, which is already showed
Member_info.pop(temp)

# To show a member info, which is defined based on user input
print(f"""
    {name_lst[temp]}'s {info_lst_common[0]} is {info_lst[0]}.
    {name_lst[temp]} 's {info_lst_common[1]} is {info_lst[1]}. {name_lst[temp]}'s' {info_lst_common[2]} is {info_lst[2]} 
    and {info_lst_common[3]} a {info_lst[3]}. 
    
    {name_lst[temp]}'s {info_lst_common[4]} is {info_lst[4]} and favorite {info_lst_common[5]} is {info_lst[5]}. 
    
    Did you know that {name_lst[temp]}'s {info_lst_common[6]} is {info_lst[6]}!!""")

print("-----------------------------------------------") 
# To remove a member name from list, which is already showed
name_lst.pop(temp)

# -----------------------------------------------------------------------------------------------------------------------

# user inputs message for the group
print("You made it to the end. Please type your message.") 
message = input()

# closing statement showing the user name

print(f"""It's been fun {visitor}. Thanks for the message""")
# Out:
# What's your name:
# Chase
# Hello Chase. Welcome to group 10's dynamic introduction.
#
# Pick one name from the list below, that you want to know
# ['Ryo', 'Roger', 'Bianca', 'Piyush', 'Tebatso']
# Name :
# Roger
#
#     Roger's hobbies is Golf.
#     Roger 's nationality is Spanish. Roger's' work background is Marketing Manager
#     and aspires to be a Mark Zuckerberg.
#
#     Roger's favorite cuisine is Japanese and favorite travel destination is Mars and beyond.
#
#     Did you know that Roger's special talents is sleeping on a plane!!
# -----------------------------------------------
#
# Pick one name from the list below, that you want to know
# ['Ryo', 'Bianca', 'Piyush', 'Tebatso']
# Name :
# Ryo
#
#     Ryo's hobbies is Basketball.
#     Ryo 's nationality is Japanese. Ryo's' work background is IT
#     and aspires to be a Data Scientist.
#
#     Ryo's favorite cuisine is Ramen and favorite travel destination is Moon.
#
# ...
